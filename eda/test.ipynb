# %% [markdown]
# This is for PlayGround

# %%
import pandas as pd

# %%
dataset_dummy = {
    "name" : ['A','B','c'],
    "age" : [10,20,30]
}

# %%
df = pd.DataFrame(dataset_dummy)
df
# Out:
#   name  age
# 0    A   10
# 1    B   20
# 2    c   30
