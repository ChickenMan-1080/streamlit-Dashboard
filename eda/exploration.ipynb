# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
print(os.getcwd()) # Get Current Working Directory ดูว่าเราอยู่ที่ไหนในระบบไฟล์
# Out:
# d:\Phee\Python project\streamlit-Dashboard\eda

# %%
df = pd.read_csv('../assets/AI_Job_Market_Trends_2026.csv')
df
# Out:
#        job_id                  job_title company_size company_industry  \
# 0           1                AI Engineer      Startup           Retail
# 1           2  Machine Learning Engineer          MNC       Technology
# 2           3  Machine Learning Engineer          MNC       Technology
# 3           4           Business Analyst      Startup       Healthcare
# 4           5             Data Scientist          MNC       Healthcare
# ...       ...                        ...          ...              ...
# 10340   10341              Data Engineer      Startup       Technology
# 10341   10342               Data Analyst       Medium       Healthcare
# 10342   10343  Machine Learning Engineer      Startup        Education
# 10343   10344              Data Engineer          MNC       E-commerce
# 10344   10345                AI Engineer      Startup        Education
#
#          country remote_type experience_level  years_experience  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                10345 non-null  int64
#  1   job_title             10345 non-null  object
#  2   company_size          10345 non-null  object
#  3   company_industry      10345 non-null  object
#  4   country               10345 non-null  object
#  5   remote_type           10345 non-null  object
#  6   experience_level      10345 non-null  object
#  7   years_experience      10345 non-null  int64
#  8   education_level       10345 non-null  object
#  9   skills_python         10345 non-null  int64
#  10  skills_sql            10345 non-null  int64
#  11  skills_ml             10345 non-null  int64
#  12  skills_deep_learning  10345 non-null  int64
#  13  skills_cloud          10345 non-null  int64
#  14  salary                10345 non-null  int64
# ...

# %%
df.describe() # อย่าอ่านข้อมูลที่เป็น 0,1 เพราะเป็นข้อมูลเชิงหมวดหมู่ ไม่ใช่ตัวเลข
# Out:
#              job_id  years_experience  skills_python    skills_sql  \
# count  10345.000000      10345.000000   10345.000000  10345.000000
# mean    5173.000000          6.950507       0.493088      0.503045
# std     2986.488601          4.320054       0.499976      0.500015
# min        1.000000          0.000000       0.000000      0.000000
# 25%     2587.000000          3.000000       0.000000      0.000000
# 50%     5173.000000          7.000000       0.000000      1.000000
# 75%     7759.000000         11.000000       1.000000      1.000000
# max    10345.000000         14.000000       1.000000      1.000000
#
#           skills_ml  skills_deep_learning  skills_cloud        salary  \
# count  10345.000000          10345.000000  10345.000000   10345.00000
# mean       0.507878              0.498018      0.511455  113438.22726
# std        0.499962              0.500020      0.499893   31389.20106
# min        0.000000              0.000000      0.000000   45083.00000
# ...

# %% [markdown]
# Cleaning Data

# %%
df_clean_dashboard = df.drop(columns = ['job_id', 'job_posting_month'])
df_clean_dashboard
# Out:
#                        job_title company_size company_industry    country  \
# 0                    AI Engineer      Startup           Retail     Canada
# 1      Machine Learning Engineer          MNC       Technology  Australia
# 2      Machine Learning Engineer          MNC       Technology    Germany
# 3               Business Analyst      Startup       Healthcare    Germany
# 4                 Data Scientist          MNC       Healthcare    Germany
# ...                          ...          ...              ...        ...
# 10340              Data Engineer      Startup       Technology        USA
# 10341               Data Analyst       Medium       Healthcare  Australia
# 10342  Machine Learning Engineer      Startup        Education    Germany
# 10343              Data Engineer          MNC       E-commerce     Canada
# 10344                AI Engineer      Startup        Education  Australia
#
#       remote_type experience_level  years_experience education_level  \
# ...

# %%
df_clean_dashboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_title             10345 non-null  object
#  1   company_size          10345 non-null  object
#  2   company_industry      10345 non-null  object
#  3   country               10345 non-null  object
#  4   remote_type           10345 non-null  object
#  5   experience_level      10345 non-null  object
#  6   years_experience      10345 non-null  int64
#  7   education_level       10345 non-null  object
#  8   skills_python         10345 non-null  int64
#  9   skills_sql            10345 non-null  int64
#  10  skills_ml             10345 non-null  int64
#  11  skills_deep_learning  10345 non-null  int64
#  12  skills_cloud          10345 non-null  int64
#  13  salary                10345 non-null  int64
#  14  job_posting_year      10345 non-null  int64
# ...

# %%
#df_clean_dashboard = df_clean_dashboard.groupby(by=["job_title"]).mean()[["salary"]] #บวกไม่ได้เพราะมี object อยู่ใน column อื่น
df_average_salary = df_clean_dashboard.groupby(by=["job_title"])[["salary"]].mean()#[] จะไม่มีตาราง [[]] จะมีตาราง
# Out:
#                                   salary
# job_title
# AI Engineer                139934.655370
# Business Analyst           101642.028765
# Data Analyst                99136.475745
# Data Engineer               99711.085322
# Data Scientist              99645.837933
# Machine Learning Engineer  139705.422989

# %%
df_average_salary.reset_index()
# Out:
#                    job_title         salary
# 0                AI Engineer  139934.655370
# 1           Business Analyst  101642.028765
# 2               Data Analyst   99136.475745
# 3              Data Engineer   99711.085322
# 4             Data Scientist   99645.837933
# 5  Machine Learning Engineer  139705.422989
